# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

df = pd.read_csv("../music_reccomendations/Processed_data.csv")
rec_df = pd.read_csv("../music_reccomendations/Processed_data_rec.csv")

# %%
def optimizs_k_means(df, max_k):
    means = []
    inertias = []
    
    for k in range(1, max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(df)
        
        means.append(k)
        inertias.append(kmeans.inertia_)
        
        fig = plt.subplots(figsize= (10, 5))
        plt.plot(means, inertias, 'o-')
        plt.xlabel("Number of Clusters")
        plt.ylabel("Inertia")
        plt.grid(True)
        plt.show()

# %%
optimizs_k_means(df, 10)
# Out:
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# As we see through the analysis we can regard two number of clusters as one of the best options for our modeling however considering the variety of themes around the songs, dividing them in two could be a bit too simplistic so we can increase the number of clusters to 3 or even 4 in order to acieve a more complex modeling.

# %%
kmeans = KMeans(n_clusters=3)

kmeans.fit(df)
# Out:
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
df['kmeans_3'] = kmeans.labels_

# %%
df
# Out:
#        artist_name  release_date  genre  len    dating  violence  world/life  \
# 0             3197          1950      4   95  0.000598  0.063746    0.000598
# 1             1597          1950      4   51  0.035537  0.096777    0.443435
# 2             2300          1950      4   24  0.002770  0.002770    0.002770
# 3             3637          1950      4   54  0.048249  0.001548    0.001548
# 4             1726          1950      4   48  0.001350  0.001350    0.417772
# ...            ...           ...    ...  ...       ...       ...         ...
# 28357         2846          2019      2   78  0.001350  0.001350    0.001350
# 28358         2838          2019      2   67  0.001284  0.001284    0.035338
# 28359         3323          2019      2   77  0.001504  0.154302    0.168988
# 28360         5315          2019      2   67  0.001196  0.001196    0.001196
# 28361         2147          2019      2   83  0.001012  0.075202    0.001012
#
#        night/time  shake the audience  family/gospel  ...  communication  \
# 0        0.000598            0.000598       0.048857  ...       0.263751
# 1        0.001284            0.001284       0.027007  ...       0.001284
# 2        0.002770            0.002770       0.002770  ...       0.250668
# 3        0.001548            0.021500       0.001548  ...       0.001548
# 4        0.001350            0.001350       0.001350  ...       0.001350
# ...           ...                 ...            ...  ...            ...
# 28357    0.001350            0.001350       0.001350  ...       0.001350
# 28358    0.001284            0.001284       0.001284  ...       0.203889
# 28359    0.001504            0.039755       0.001504  ...       0.001504
# 28360    0.001196            0.048359       0.001196  ...       0.001196
# 28361    0.001012            0.001012       0.001012  ...       0.001012
#
#         obscene     music  movement/places  light/visual perceptions  \
# 0      0.000598  0.039288         0.000598                  0.000598
# 1      0.001284  0.118034         0.001284                  0.212681
# 2      0.002770  0.323794         0.002770                  0.002770
# 3      0.001548  0.001548         0.129250                  0.001548
# 4      0.001350  0.001350         0.001350                  0.001350
# ...         ...       ...              ...                       ...
# 28357  0.391651  0.001350         0.435089                  0.001350
# 28358  0.318910  0.058152         0.134955                  0.001284
# 28359  0.356685  0.001504         0.068684                  0.001504
# 28360  0.492434  0.103614         0.001196                  0.202659
# 28361  0.754444  0.046284         0.001012                  0.001012
#
#        family/spiritual   sadness  feelings  topic  kmeans_3
# 0              0.000598  0.380299  0.117175      5         2
# 1              0.051124  0.001284  0.001284      7         0
# 2              0.002770  0.002770  0.225422      1         2
# 3              0.001548  0.225889  0.001548      4         2
# 4              0.029755  0.068800  0.001350      4         0
# ...                 ...       ...       ...    ...       ...
# 28357          0.001350  0.065664  0.001350      3         2
# 28358          0.001284  0.001284  0.001284      3         2
# 28359          0.001504  0.001504  0.001504      3         2
# 28360          0.001196  0.001196  0.001196      3         1
# 28361          0.001012  0.001012  0.033995      3         2
#
# [28362 rows x 21 columns]

# %% [markdown]
# ## Plotting the Results

# %%
plt.scatter(x=df["release_date"], y=df["shake the audience"], c=df["kmeans_3"])

# %%
k_fit = kmeans.fit(df)

predictions = k_fit.labels_
type(predictions)
k_fit
# Out:
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
df = df.drop("kmeans_3", axis=1)

# %%
kmeans_rec = KMeans(n_clusters=3)

# Fit KMeans on the original data
kmeans_rec.fit(df)

# Predict clusters for the new data
predicted_clusters = kmeans_rec.predict(rec_df)



rec_df['kmeans_3'] = predicted_clusters

rec_df
# Out:
# c:\Users\neves\Anaconda3\envs\phase1\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    artist_name  release_date  genre  len    dating  violence  world/life  \
# 0            1          1998      5   74  0.000907  0.348191    0.375448
# 1            0          1993      4   43  0.001224  0.029943    0.001224
# 2            9          1990      3   54  0.001120  0.482490    0.001120
# 3            2          1960      3   25  0.204740  0.002506    0.002506
# 4            5          1966      3   97  0.001170  0.001170    0.001170
# 5            3          1952      2   57  0.001462  0.487965    0.140561
# 6            6          2000      5  152  0.000675  0.000675    0.134044
# 7            8          1970      0   37  0.051874  0.001645    0.001645
# 8            7          1986      1   41  0.001504  0.001504    0.132148
# 9            4          2009      3   91  0.000711  0.543658    0.114697
#
#    night/time  shake the audience  family/gospel  ...  communication  \
# 0    0.000907            0.225414       0.000907  ...       0.000907
# 1    0.306688            0.001224       0.033440  ...       0.426669
# 2    0.001120            0.001120       0.113651  ...       0.001120
# 3    0.129818            0.002506       0.002506  ...       0.002506
# 4    0.050289            0.001170       0.023530  ...       0.001170
# 5    0.001462            0.001462       0.001462  ...       0.238731
# 6    0.293819            0.000675       0.000675  ...       0.066012
# 7    0.084118            0.037341       0.001645  ...       0.460564
# 8    0.492312            0.001504       0.001504  ...       0.321439
# 9    0.098286            0.014720       0.000711  ...       0.075524
#
#     obscene     music  movement/places  light/visual perceptions  \
# 0  0.000907  0.019389         0.000907                  0.000907
# 1  0.001224  0.001224         0.001224                  0.001224
# 2  0.001120  0.001120         0.001120                  0.078222
# 3  0.002506  0.002506         0.002506                  0.002506
# 4  0.001170  0.001170         0.001170                  0.314626
# 5  0.001462  0.001462         0.001462                  0.001462
# 6  0.460145  0.000675         0.000675                  0.000675
# 7  0.001645  0.001645         0.001645                  0.001645
# 8  0.001504  0.001504         0.001504                  0.001504
# 9  0.000711  0.000711         0.000711                  0.000711
#
#    family/spiritual   sadness  feelings  topic  kmeans_3
# 0          0.000907  0.000907  0.018854      5         1
# 1          0.001224  0.001224  0.062092      0         1
# 2          0.001120  0.031571  0.202862      4         1
# 3          0.002506  0.474607  0.002506      3         1
# 4          0.001170  0.001170  0.001170      2         1
# 5          0.077630  0.001462  0.034645      4         1
# 6          0.024217  0.000675  0.000675      1         1
# 7          0.001645  0.314594  0.001645      3         1
# 8          0.001504  0.001504  0.001504      0         1
# 9          0.000711  0.118886  0.015028      4         1
#
# [10 rows x 21 columns]

# %%
df['kmeans_3'] = kmeans.labels_

reccomend = df["kmeans_3"] == 2

reccomend.
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 28357     True
# 28358     True
# 28359     True
# 28360    False
# 28361     True
# Name: kmeans_3, Length: 28362, dtype: bool
